# %% [markdown]
# ## Solving CartPole-V1 using REINFORCE Algorithm
#
#
# The description of the CartPole-v1 as given on the OpenAI gym website -
#
# """
#
# A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. The episode ends when the pole is more than 15 degrees from vertical, or the cart moves more than 2.4 units from the center.
#
# """
#
# This environment corresponds to the version of the cart-pole problem described by Barto, Sutton, and Anderson.

# %%
import os
import gym
import numpy as np

# MXNET
from mxnet import nd, gluon, init, autograd
from mxnet.gluon import nn
import mxnet as mx

# %%
class REINFORCE(object):
    def __init__(self, env, lr=1e-3, seed=42):
        """
        REINFORCE algorithm implementation.
        
        Args:
            env (Gym environment) : the environment that we are training our reinforcement learning.
            lr (float) : the learning rate used for to update the neural network.
            seed (int) : the random seed used to generate data from the environment.
        """

        self.env = env
        self.lr = lr
        self.seed = seed
        self.env.seed(self.seed)
        
        print('Random seed: {} '.format(seed))

        self.build_network()
        
        
    def build_network(self, hidden_size=20):
        """
        Build the neural network and set up the trainer.
        
        Args:
            hidden_size (int) : the size of the hidden layers in the neural network.
        """    
        
        self.policy_net = nn.Sequential()
        self.policy_net.add(nn.Dense(hidden_size, activation="relu"),
                            nn.Dense(hidden_size, activation="relu"),
                            nn.Dense(self.env.action_space.n))
        self.policy_net.initialize(init=init.Xavier())

        self.trainer = gluon.Trainer(self.policy_net.collect_params(), 'adam', {'learning_rate': self.lr})

        
    def update(self, lr_coeff=0.999):
        """
        Perform an update on a batch of data collected during an episode. It will also reduce the learning rate 
        after the update as a way to improve convergence.
        
        Args:
            lr_coeff (float) : the coefficient with which we multiply the current learning rate.
        """
        
        returns    = self.get_returns()
        batch_size = len(self.actions)

        with autograd.record():
            all_actions = nd.softmax(self.policy_net(nd.array(self.states[:-1])))
            
            loss = - nd.log(all_actions[np.array(range(batch_size)), np.array(self.actions)]) * returns

        loss.backward()
        
        self.trainer.step(batch_size)
        self.trainer.set_learning_rate(self.trainer.learning_rate * lr_coeff) 
      
    
    def predict(self,  state):
        """
        Output the probabilities for all actions and choose stochastically one of them.
        
        Args:
            state (array of floats) : the state for which we want to select an action.
        Returns:
            action (int) : the selected action given the state.
        """
        
        actions = nd.softmax(self.policy_net(nd.array([state]))).asnumpy()[0]

        return np.random.choice(len(actions), p=actions)
    
    
    def get_returns(self, discount_factor=0.99):
        """
        Calculate the return for every state. This is defined as the discounted 
        sum of rewards after visiting the state. 
        
        Args:
            discount_factor (float) : determines how much we care about distant 
                                        rewards (1.0) vs immediate rewards (0.).
        Returns:
            normalized_returns (array of float) : the returns, from which the mean is 
                                                 substracted to reduce the variance.
        """
        returns=[]
        curr_sum = 0.
        for r in reversed(self.rewards):
            curr_sum = r + discount_factor*curr_sum
            returns.append(curr_sum)
            
        returns.reverse()
        normalized_returns = nd.array(returns) - nd.mean(nd.array(returns))
        
        return normalized_returns
    
    
    def setup_saving(self):
        """
        Store results.
        
        Args:
            None
        
        Returns:
            printout of location of stored file.
        """
        
        directory= os.getcwd() + '/res/'
        if not os.path.exists(directory):
            os.makedirs(directory)
            
        save_file = "{}cartpole_seed{}.csv".format(directory,self.seed)
        
        return save_file, []   
    
    
    def initialize_episode(self):
        """
        Initialiazes the variables total_rewards, ewards, actions and states, and
        resets the environment.
        
        Returns:
            state (array of float) : the first state of the episode.
        """
        
        self.rewards,self.actions,self.states = [],[],[]
        self.total_rewards = 0.

        state = self.env.reset()
        self.states.append(state) 

        return state

    
    def add_to_trajectory(self, action, next_state, reward):
        """
        Stores in memory the action, next_state and reward. This will later be used for updates.
        
        Args:
            action (int) : the selected action in the current state.
            action (int) : the reward after selectin the action.
            next_state (array of floats) : the next state returned by the environment after selecting the action.
        Returns:
            next_state (array of float) : the next state returned by the environment after selecting the action.
        """
        
        self.total_rewards += reward
        
        self.rewards.append(reward)
        self.actions.append(action)   
        self.states.append(next_state)

        return next_state
    

    def fit(self, num_episodes=1000, save_every=5):
        """
        Implements the training loop. 
        
        Args:
            num_episodes (int) : the number of episodes we train the agent.
            save_every (int) : the rate at which we save the results, which will be used for visualization.
        """
        
        save_file, stats = self.setup_saving()

        for i_episode in range(num_episodes):
            if i_episode % save_every == 0 and i_episode != 0:
                np.savetxt(save_file,stats,delimiter=',') 

            state = self.initialize_episode()
            done=False
            t=0

            while not done:
                t+=1
                action = self.predict(state)
                next_state, reward, done, _ = self.env.step(action)
                state = self.add_to_trajectory(action, next_state, reward)
                if i_episode%50 ==0:self.env.render()

            print("\rEpisode {} Total Rewards {} ".format(i_episode, self.total_rewards) )
            stats.append(t)
            self.update()

# %%
env = gym.make("CartPole-v1")

# %%
REINFORCE(env).fit()
# Out:
# Random seed: 42
# Episode 0 Total Rewards 26.0
# Episode 1 Total Rewards 14.0
# Episode 2 Total Rewards 59.0
# Episode 3 Total Rewards 27.0
# Episode 4 Total Rewards 11.0
# Episode 5 Total Rewards 23.0
# Episode 6 Total Rewards 11.0
# Episode 7 Total Rewards 11.0
# Episode 8 Total Rewards 16.0
# Episode 9 Total Rewards 39.0
# Episode 10 Total Rewards 47.0
# Episode 11 Total Rewards 17.0
# Episode 12 Total Rewards 24.0
# Episode 13 Total Rewards 20.0
# Episode 14 Total Rewards 16.0
# Episode 15 Total Rewards 38.0
# Episode 16 Total Rewards 55.0
# Episode 17 Total Rewards 16.0
# Episode 18 Total Rewards 19.0
# Episode 19 Total Rewards 59.0
# Episode 20 Total Rewards 25.0
# Episode 21 Total Rewards 36.0
# Episode 22 Total Rewards 26.0
# Episode 23 Total Rewards 47.0
# Episode 24 Total Rewards 13.0
# Episode 25 Total Rewards 30.0
# Episode 26 Total Rewards 17.0
# Episode 27 Total Rewards 31.0
# Episode 28 Total Rewards 18.0
# Episode 29 Total Rewards 22.0
# Episode 30 Total Rewards 14.0
# Episode 31 Total Rewards 23.0
# Episode 32 Total Rewards 14.0
# Episode 33 Total Rewards 26.0
# Episode 34 Total Rewards 22.0
# Episode 35 Total Rewards 22.0
# Episode 36 Total Rewards 54.0
# Episode 37 Total Rewards 15.0
# Episode 38 Total Rewards 10.0
# Episode 39 Total Rewards 57.0
# Episode 40 Total Rewards 8.0
# Episode 41 Total Rewards 32.0
# Episode 42 Total Rewards 9.0
# Episode 43 Total Rewards 58.0
# Episode 44 Total Rewards 49.0
# Episode 45 Total Rewards 10.0
# Episode 46 Total Rewards 42.0
# Episode 47 Total Rewards 41.0
# Episode 48 Total Rewards 36.0
# Episode 49 Total Rewards 22.0
# Episode 50 Total Rewards 49.0
# Episode 51 Total Rewards 28.0
# Episode 52 Total Rewards 29.0
# Episode 53 Total Rewards 42.0
# Episode 54 Total Rewards 23.0
# Episode 55 Total Rewards 37.0
# Episode 56 Total Rewards 45.0
# Episode 57 Total Rewards 13.0
# Episode 58 Total Rewards 21.0
# Episode 59 Total Rewards 82.0
# Episode 60 Total Rewards 44.0
# Episode 61 Total Rewards 17.0
# Episode 62 Total Rewards 37.0
# Episode 63 Total Rewards 13.0
# Episode 64 Total Rewards 12.0
# Episode 65 Total Rewards 20.0
# Episode 66 Total Rewards 73.0
# Episode 67 Total Rewards 27.0
# Episode 68 Total Rewards 19.0
# Episode 69 Total Rewards 17.0
# Episode 70 Total Rewards 12.0
# Episode 71 Total Rewards 47.0
# Episode 72 Total Rewards 27.0
# Episode 73 Total Rewards 27.0
# Episode 74 Total Rewards 15.0
# Episode 75 Total Rewards 15.0
# Episode 76 Total Rewards 11.0
# Episode 77 Total Rewards 11.0
# Episode 78 Total Rewards 14.0
# Episode 79 Total Rewards 11.0
# Episode 80 Total Rewards 30.0
# Episode 81 Total Rewards 72.0
# Episode 82 Total Rewards 18.0
# Episode 83 Total Rewards 14.0
# Episode 84 Total Rewards 22.0
# Episode 85 Total Rewards 41.0
# Episode 86 Total Rewards 23.0
# Episode 87 Total Rewards 32.0
# Episode 88 Total Rewards 17.0
# Episode 89 Total Rewards 30.0
# Episode 90 Total Rewards 25.0
# Episode 91 Total Rewards 9.0
# Episode 92 Total Rewards 21.0
# Episode 93 Total Rewards 40.0
# Episode 94 Total Rewards 30.0
# Episode 95 Total Rewards 28.0
# Episode 96 Total Rewards 44.0
# Episode 97 Total Rewards 36.0
# Episode 98 Total Rewards 63.0
# Episode 99 Total Rewards 78.0
# Episode 100 Total Rewards 54.0
# Episode 101 Total Rewards 13.0
# Episode 102 Total Rewards 31.0
# Episode 103 Total Rewards 37.0
# Episode 104 Total Rewards 52.0
# Episode 105 Total Rewards 40.0
# Episode 106 Total Rewards 27.0
# Episode 107 Total Rewards 13.0
# Episode 108 Total Rewards 21.0
# Episode 109 Total Rewards 12.0
# Episode 110 Total Rewards 43.0
# Episode 111 Total Rewards 29.0
# Episode 112 Total Rewards 25.0
# Episode 113 Total Rewards 15.0
# Episode 114 Total Rewards 15.0
# Episode 115 Total Rewards 30.0
# Episode 116 Total Rewards 9.0
# Episode 117 Total Rewards 26.0
# Episode 118 Total Rewards 20.0
# Episode 119 Total Rewards 88.0
# Episode 120 Total Rewards 14.0
# Episode 121 Total Rewards 21.0
# Episode 122 Total Rewards 63.0
# Episode 123 Total Rewards 71.0
# Episode 124 Total Rewards 104.0
# Episode 125 Total Rewards 44.0
# Episode 126 Total Rewards 24.0
# Episode 127 Total Rewards 25.0
# Episode 128 Total Rewards 36.0
# Episode 129 Total Rewards 29.0
# Episode 130 Total Rewards 67.0
# Episode 131 Total Rewards 15.0
# Episode 132 Total Rewards 14.0
# Episode 133 Total Rewards 18.0
# Episode 134 Total Rewards 29.0
# Episode 135 Total Rewards 16.0
# Episode 136 Total Rewards 29.0
# Episode 137 Total Rewards 51.0
# Episode 138 Total Rewards 27.0
# Episode 139 Total Rewards 29.0
# Episode 140 Total Rewards 18.0
# Episode 141 Total Rewards 35.0
# Episode 142 Total Rewards 23.0
# Episode 143 Total Rewards 20.0
# Episode 144 Total Rewards 38.0
# Episode 145 Total Rewards 38.0
# Episode 146 Total Rewards 59.0
# Episode 147 Total Rewards 19.0
# Episode 148 Total Rewards 24.0
# Episode 149 Total Rewards 22.0
# Episode 150 Total Rewards 39.0
# Episode 151 Total Rewards 30.0
# Episode 152 Total Rewards 27.0
# Episode 153 Total Rewards 26.0
# Episode 154 Total Rewards 22.0
# Episode 155 Total Rewards 24.0
# Episode 156 Total Rewards 18.0
# Episode 157 Total Rewards 24.0
# Episode 158 Total Rewards 17.0
# Episode 159 Total Rewards 47.0
# Episode 160 Total Rewards 32.0
# Episode 161 Total Rewards 43.0
# Episode 162 Total Rewards 20.0
# Episode 163 Total Rewards 57.0
# Episode 164 Total Rewards 16.0
# Episode 165 Total Rewards 15.0
# Episode 166 Total Rewards 62.0
# Episode 167 Total Rewards 18.0
# Episode 168 Total Rewards 31.0
# Episode 169 Total Rewards 94.0
# Episode 170 Total Rewards 17.0
# Episode 171 Total Rewards 15.0
# Episode 172 Total Rewards 11.0
# Episode 173 Total Rewards 93.0
# Episode 174 Total Rewards 72.0
# Episode 175 Total Rewards 58.0
# Episode 176 Total Rewards 32.0
# Episode 177 Total Rewards 65.0
# Episode 178 Total Rewards 34.0
# Episode 179 Total Rewards 37.0
# Episode 180 Total Rewards 93.0
# Episode 181 Total Rewards 29.0
# Episode 182 Total Rewards 17.0
# Episode 183 Total Rewards 55.0
# Episode 184 Total Rewards 91.0
# Episode 185 Total Rewards 14.0
# Episode 186 Total Rewards 22.0
# Episode 187 Total Rewards 24.0
# Episode 188 Total Rewards 82.0
# Episode 189 Total Rewards 53.0
# Episode 190 Total Rewards 23.0
# Episode 191 Total Rewards 35.0
# Episode 192 Total Rewards 72.0
# Episode 193 Total Rewards 25.0
# Episode 194 Total Rewards 30.0
# Episode 195 Total Rewards 24.0
# Episode 196 Total Rewards 28.0
# Episode 197 Total Rewards 10.0
# Episode 198 Total Rewards 31.0
# Episode 199 Total Rewards 12.0
# Episode 200 Total Rewards 27.0
# Episode 201 Total Rewards 32.0
# Episode 202 Total Rewards 74.0
# Episode 203 Total Rewards 38.0
# Episode 204 Total Rewards 39.0
# Episode 205 Total Rewards 45.0
# Episode 206 Total Rewards 51.0
# Episode 207 Total Rewards 12.0
# Episode 208 Total Rewards 39.0
# Episode 209 Total Rewards 24.0
# Episode 210 Total Rewards 41.0
# Episode 211 Total Rewards 68.0
# Episode 212 Total Rewards 31.0
# Episode 213 Total Rewards 30.0
# Episode 214 Total Rewards 41.0
# Episode 215 Total Rewards 18.0
# Episode 216 Total Rewards 52.0
# Episode 217 Total Rewards 47.0
# Episode 218 Total Rewards 24.0
# Episode 219 Total Rewards 21.0
# Episode 220 Total Rewards 28.0
# Episode 221 Total Rewards 63.0
# Episode 222 Total Rewards 36.0
# Episode 223 Total Rewards 27.0
# Episode 224 Total Rewards 54.0
# Episode 225 Total Rewards 40.0
# Episode 226 Total Rewards 36.0
# Episode 227 Total Rewards 86.0
# Episode 228 Total Rewards 23.0
# Episode 229 Total Rewards 43.0
# Episode 230 Total Rewards 122.0
# Episode 231 Total Rewards 102.0
# Episode 232 Total Rewards 22.0
# Episode 233 Total Rewards 90.0
# Episode 234 Total Rewards 25.0
# Episode 235 Total Rewards 78.0
# Episode 236 Total Rewards 34.0
# Episode 237 Total Rewards 121.0
# Episode 238 Total Rewards 86.0
# Episode 239 Total Rewards 30.0
# Episode 240 Total Rewards 24.0
# Episode 241 Total Rewards 34.0
# Episode 242 Total Rewards 66.0
# Episode 243 Total Rewards 19.0
# Episode 244 Total Rewards 108.0
# Episode 245 Total Rewards 24.0
# Episode 246 Total Rewards 13.0
# Episode 247 Total Rewards 22.0
# Episode 248 Total Rewards 46.0
# Episode 249 Total Rewards 111.0
# Episode 250 Total Rewards 52.0
# Episode 251 Total Rewards 31.0
# Episode 252 Total Rewards 19.0
# Episode 253 Total Rewards 42.0
# Episode 254 Total Rewards 26.0
# Episode 255 Total Rewards 95.0
# Episode 256 Total Rewards 66.0
# Episode 257 Total Rewards 53.0
# Episode 258 Total Rewards 26.0
# Episode 259 Total Rewards 69.0
# Episode 260 Total Rewards 45.0
# Episode 261 Total Rewards 32.0
# Episode 262 Total Rewards 67.0
# Episode 263 Total Rewards 24.0
# Episode 264 Total Rewards 78.0
# Episode 265 Total Rewards 175.0
# Episode 266 Total Rewards 80.0
# Episode 267 Total Rewards 138.0
# Episode 268 Total Rewards 22.0
# Episode 269 Total Rewards 49.0
# Episode 270 Total Rewards 123.0
# Episode 271 Total Rewards 48.0
# Episode 272 Total Rewards 36.0
# Episode 273 Total Rewards 71.0
# Episode 274 Total Rewards 104.0
# Episode 275 Total Rewards 42.0
# Episode 276 Total Rewards 68.0
# Episode 277 Total Rewards 27.0
# Episode 278 Total Rewards 108.0
# Episode 279 Total Rewards 29.0
# Episode 280 Total Rewards 73.0
# Episode 281 Total Rewards 95.0
# Episode 282 Total Rewards 13.0
# Episode 283 Total Rewards 13.0
# Episode 284 Total Rewards 51.0
# Episode 285 Total Rewards 33.0
# Episode 286 Total Rewards 66.0
# Episode 287 Total Rewards 193.0
# Episode 288 Total Rewards 70.0
# Episode 289 Total Rewards 167.0
# Episode 290 Total Rewards 92.0
# Episode 291 Total Rewards 39.0
# Episode 292 Total Rewards 84.0
# Episode 293 Total Rewards 86.0
# Episode 294 Total Rewards 89.0
# Episode 295 Total Rewards 136.0
# Episode 296 Total Rewards 91.0
# Episode 297 Total Rewards 103.0
# Episode 298 Total Rewards 136.0
# Episode 299 Total Rewards 113.0
# Episode 300 Total Rewards 94.0
# Episode 301 Total Rewards 27.0
# Episode 302 Total Rewards 73.0
# Episode 303 Total Rewards 83.0
# Episode 304 Total Rewards 54.0
# Episode 305 Total Rewards 95.0
# Episode 306 Total Rewards 154.0
# Episode 307 Total Rewards 97.0
# Episode 308 Total Rewards 60.0
# Episode 309 Total Rewards 118.0
# Episode 310 Total Rewards 145.0
# Episode 311 Total Rewards 37.0
# Episode 312 Total Rewards 59.0
# Episode 313 Total Rewards 73.0
# Episode 314 Total Rewards 88.0
# Episode 315 Total Rewards 89.0
# Episode 316 Total Rewards 140.0
# Episode 317 Total Rewards 101.0
# Episode 318 Total Rewards 104.0
# Episode 319 Total Rewards 180.0
# Episode 320 Total Rewards 75.0
# Episode 321 Total Rewards 103.0
# Episode 322 Total Rewards 43.0
# Episode 323 Total Rewards 74.0
# Episode 324 Total Rewards 99.0
# Episode 325 Total Rewards 104.0
# Episode 326 Total Rewards 35.0
# Episode 327 Total Rewards 77.0
# Episode 328 Total Rewards 184.0
# Episode 329 Total Rewards 137.0
# Episode 330 Total Rewards 211.0
# Episode 331 Total Rewards 152.0
# Episode 332 Total Rewards 42.0
# Episode 333 Total Rewards 31.0
# Episode 334 Total Rewards 23.0
# Episode 335 Total Rewards 150.0
# Episode 336 Total Rewards 134.0
# Episode 337 Total Rewards 92.0
# Episode 338 Total Rewards 120.0
# Episode 339 Total Rewards 68.0
# Episode 340 Total Rewards 244.0
# Episode 341 Total Rewards 163.0
# Episode 342 Total Rewards 71.0
# Episode 343 Total Rewards 16.0
# Episode 344 Total Rewards 157.0
# Episode 345 Total Rewards 154.0
# Episode 346 Total Rewards 120.0
# Episode 347 Total Rewards 97.0
# Episode 348 Total Rewards 230.0
# Episode 349 Total Rewards 166.0
# Episode 350 Total Rewards 83.0
# Episode 351 Total Rewards 115.0
# Episode 352 Total Rewards 57.0
# Episode 353 Total Rewards 46.0
# Episode 354 Total Rewards 133.0
# Episode 355 Total Rewards 193.0
# Episode 356 Total Rewards 116.0
# Episode 357 Total Rewards 55.0
# Episode 358 Total Rewards 92.0
# Episode 359 Total Rewards 130.0
# Episode 360 Total Rewards 245.0
# Episode 361 Total Rewards 84.0
# Episode 362 Total Rewards 140.0
# Episode 363 Total Rewards 173.0
# Episode 364 Total Rewards 149.0
# Episode 365 Total Rewards 267.0
# Episode 366 Total Rewards 96.0
# Episode 367 Total Rewards 158.0
# Episode 368 Total Rewards 287.0
# Episode 369 Total Rewards 41.0
# Episode 370 Total Rewards 145.0
# Episode 371 Total Rewards 47.0
# Episode 372 Total Rewards 193.0
# Episode 373 Total Rewards 23.0
# Episode 374 Total Rewards 115.0
# Episode 375 Total Rewards 154.0
# Episode 376 Total Rewards 106.0
# Episode 377 Total Rewards 361.0
# Episode 378 Total Rewards 110.0
# Episode 379 Total Rewards 103.0
# Episode 380 Total Rewards 127.0
# Episode 381 Total Rewards 194.0
# Episode 382 Total Rewards 365.0
# Episode 383 Total Rewards 305.0
# Episode 384 Total Rewards 124.0
# Episode 385 Total Rewards 192.0
# Episode 386 Total Rewards 75.0
# Episode 387 Total Rewards 340.0
# Episode 388 Total Rewards 134.0
# Episode 389 Total Rewards 500.0
# Episode 390 Total Rewards 377.0
# Episode 391 Total Rewards 30.0
# Episode 392 Total Rewards 253.0
# Episode 393 Total Rewards 303.0
# Episode 394 Total Rewards 225.0
# Episode 395 Total Rewards 26.0
# Episode 396 Total Rewards 102.0
# Episode 397 Total Rewards 267.0
# Episode 398 Total Rewards 134.0
# Episode 399 Total Rewards 126.0
# Episode 400 Total Rewards 122.0
# Episode 401 Total Rewards 81.0
# Episode 402 Total Rewards 137.0
# Episode 403 Total Rewards 161.0
# Episode 404 Total Rewards 283.0
# Episode 405 Total Rewards 186.0
# Episode 406 Total Rewards 98.0
# Episode 407 Total Rewards 114.0
# Episode 408 Total Rewards 311.0
# Episode 409 Total Rewards 211.0
# Episode 410 Total Rewards 166.0
# Episode 411 Total Rewards 195.0
# Episode 412 Total Rewards 187.0
# Episode 413 Total Rewards 126.0
# Episode 414 Total Rewards 152.0
# Episode 415 Total Rewards 255.0
# Episode 416 Total Rewards 204.0
# Episode 417 Total Rewards 169.0
# Episode 418 Total Rewards 121.0
# Episode 419 Total Rewards 180.0
# Episode 420 Total Rewards 130.0
# Episode 421 Total Rewards 136.0
# Episode 422 Total Rewards 145.0
# Episode 423 Total Rewards 110.0
# Episode 424 Total Rewards 89.0
# Episode 425 Total Rewards 101.0
# Episode 426 Total Rewards 226.0
# Episode 427 Total Rewards 249.0
# Episode 428 Total Rewards 386.0
# Episode 429 Total Rewards 128.0
# Episode 430 Total Rewards 225.0
# Episode 431 Total Rewards 144.0
# Episode 432 Total Rewards 314.0
# Episode 433 Total Rewards 122.0
# Episode 434 Total Rewards 336.0
# Episode 435 Total Rewards 234.0
# Episode 436 Total Rewards 236.0
# Episode 437 Total Rewards 129.0
# Episode 438 Total Rewards 211.0
# Episode 439 Total Rewards 210.0
# Episode 440 Total Rewards 216.0
# Episode 441 Total Rewards 160.0
# Episode 442 Total Rewards 55.0
# Episode 443 Total Rewards 120.0
# Episode 444 Total Rewards 108.0
# Episode 445 Total Rewards 19.0
# Episode 446 Total Rewards 139.0
# Episode 447 Total Rewards 195.0
# Episode 448 Total Rewards 192.0
# Episode 449 Total Rewards 236.0
# Episode 450 Total Rewards 180.0
# Episode 451 Total Rewards 222.0
# Episode 452 Total Rewards 204.0
# Episode 453 Total Rewards 181.0
# Episode 454 Total Rewards 84.0
# Episode 455 Total Rewards 226.0
# Episode 456 Total Rewards 472.0
# Episode 457 Total Rewards 217.0
# Episode 458 Total Rewards 246.0
# Episode 459 Total Rewards 215.0
# Episode 460 Total Rewards 240.0
# Episode 461 Total Rewards 188.0
# Episode 462 Total Rewards 212.0
# Episode 463 Total Rewards 370.0
# Episode 464 Total Rewards 181.0
# Episode 465 Total Rewards 207.0
# Episode 466 Total Rewards 245.0
# Episode 467 Total Rewards 206.0
# Episode 468 Total Rewards 213.0
# Episode 469 Total Rewards 221.0
# Episode 470 Total Rewards 500.0
# Episode 471 Total Rewards 272.0
# Episode 472 Total Rewards 128.0
# Episode 473 Total Rewards 340.0
# Episode 474 Total Rewards 355.0
# Episode 475 Total Rewards 185.0
# Episode 476 Total Rewards 189.0
# Episode 477 Total Rewards 500.0
# Episode 478 Total Rewards 324.0
# Episode 479 Total Rewards 462.0
# Episode 480 Total Rewards 290.0
# Episode 481 Total Rewards 193.0
# Episode 482 Total Rewards 268.0
# Episode 483 Total Rewards 266.0
# Episode 484 Total Rewards 344.0
# Episode 485 Total Rewards 256.0
# Episode 486 Total Rewards 158.0
# Episode 487 Total Rewards 18.0
# Episode 488 Total Rewards 290.0
# Episode 489 Total Rewards 216.0
# Episode 490 Total Rewards 184.0
# Episode 491 Total Rewards 372.0
# Episode 492 Total Rewards 252.0
# Episode 493 Total Rewards 251.0
# Episode 494 Total Rewards 112.0
# Episode 495 Total Rewards 278.0
# Episode 496 Total Rewards 243.0
# Episode 497 Total Rewards 294.0
# Episode 498 Total Rewards 116.0
# Episode 499 Total Rewards 219.0
# Episode 500 Total Rewards 301.0
# Episode 501 Total Rewards 153.0
# Episode 502 Total Rewards 298.0
# Episode 503 Total Rewards 202.0
# Episode 504 Total Rewards 156.0
# Episode 505 Total Rewards 263.0
# Episode 506 Total Rewards 269.0
# Episode 507 Total Rewards 347.0
# Episode 508 Total Rewards 414.0
# Episode 509 Total Rewards 170.0
# Episode 510 Total Rewards 443.0
# Episode 511 Total Rewards 474.0
# Episode 512 Total Rewards 222.0
# Episode 513 Total Rewards 174.0
# Episode 514 Total Rewards 500.0
# Episode 515 Total Rewards 397.0
# Episode 516 Total Rewards 220.0
# Episode 517 Total Rewards 500.0
# Episode 518 Total Rewards 242.0
# Episode 519 Total Rewards 329.0
# Episode 520 Total Rewards 500.0
# Episode 521 Total Rewards 254.0
# Episode 522 Total Rewards 109.0
# Episode 523 Total Rewards 311.0
# Episode 524 Total Rewards 258.0
# Episode 525 Total Rewards 262.0
# Episode 526 Total Rewards 170.0
# Episode 527 Total Rewards 500.0
# Episode 528 Total Rewards 278.0
# Episode 529 Total Rewards 240.0
# Episode 530 Total Rewards 500.0
# Episode 531 Total Rewards 451.0
# Episode 532 Total Rewards 406.0
# Episode 533 Total Rewards 451.0
# Episode 534 Total Rewards 251.0
# Episode 535 Total Rewards 491.0
# Episode 536 Total Rewards 429.0
# Episode 537 Total Rewards 222.0
# Episode 538 Total Rewards 311.0
# Episode 539 Total Rewards 249.0
# Episode 540 Total Rewards 297.0
# Episode 541 Total Rewards 400.0
# Episode 542 Total Rewards 215.0
# Episode 543 Total Rewards 237.0
# Episode 544 Total Rewards 342.0
# Episode 545 Total Rewards 272.0
# Episode 546 Total Rewards 205.0
# Episode 547 Total Rewards 500.0
# Episode 548 Total Rewards 150.0
# Episode 549 Total Rewards 482.0
# Episode 550 Total Rewards 456.0
# Episode 551 Total Rewards 376.0
# Episode 552 Total Rewards 239.0
# Episode 553 Total Rewards 401.0
# Episode 554 Total Rewards 229.0
# Episode 555 Total Rewards 437.0
# Episode 556 Total Rewards 391.0
# Episode 557 Total Rewards 228.0
# Episode 558 Total Rewards 288.0
# Episode 559 Total Rewards 286.0
# Episode 560 Total Rewards 500.0
# Episode 561 Total Rewards 500.0
# Episode 562 Total Rewards 500.0
# Episode 563 Total Rewards 310.0
# Episode 564 Total Rewards 408.0
# Episode 565 Total Rewards 336.0
# Episode 566 Total Rewards 238.0
# Episode 567 Total Rewards 393.0
# Episode 568 Total Rewards 169.0
# Episode 569 Total Rewards 166.0
# Episode 570 Total Rewards 246.0
# Episode 571 Total Rewards 300.0
# Episode 572 Total Rewards 222.0
# Episode 573 Total Rewards 248.0
# Episode 574 Total Rewards 491.0
# Episode 575 Total Rewards 500.0
# Episode 576 Total Rewards 228.0
# Episode 577 Total Rewards 318.0
# Episode 578 Total Rewards 251.0
# Episode 579 Total Rewards 451.0
# Episode 580 Total Rewards 234.0
# Episode 581 Total Rewards 306.0
# Episode 582 Total Rewards 500.0
# Episode 583 Total Rewards 284.0
# Episode 584 Total Rewards 207.0
# Episode 585 Total Rewards 307.0
# Episode 586 Total Rewards 269.0
# Episode 587 Total Rewards 332.0
# Episode 588 Total Rewards 304.0
# Episode 589 Total Rewards 349.0
# Episode 590 Total Rewards 488.0
# Episode 591 Total Rewards 268.0
# Episode 592 Total Rewards 292.0
# Episode 593 Total Rewards 199.0
# Episode 594 Total Rewards 333.0
# Episode 595 Total Rewards 242.0
# Episode 596 Total Rewards 208.0
# Episode 597 Total Rewards 278.0
# Episode 598 Total Rewards 500.0
# Episode 599 Total Rewards 284.0
# Episode 600 Total Rewards 175.0
# Episode 601 Total Rewards 312.0
# Episode 602 Total Rewards 500.0
# Episode 603 Total Rewards 165.0
# Episode 604 Total Rewards 416.0
# Episode 605 Total Rewards 305.0
# Episode 606 Total Rewards 275.0
# Episode 607 Total Rewards 332.0
# Episode 608 Total Rewards 182.0
# Episode 609 Total Rewards 248.0
# Episode 610 Total Rewards 217.0
# Episode 611 Total Rewards 331.0
# Episode 612 Total Rewards 227.0
# Episode 613 Total Rewards 333.0
# Episode 614 Total Rewards 339.0
# Episode 615 Total Rewards 185.0
# Episode 616 Total Rewards 392.0
# Episode 617 Total Rewards 420.0
# Episode 618 Total Rewards 278.0
# Episode 619 Total Rewards 182.0
# Episode 620 Total Rewards 332.0
# Episode 621 Total Rewards 237.0
# Episode 622 Total Rewards 69.0
# Episode 623 Total Rewards 154.0
# Episode 624 Total Rewards 243.0
# Episode 625 Total Rewards 469.0
# Episode 626 Total Rewards 245.0
# Episode 627 Total Rewards 259.0
# Episode 628 Total Rewards 500.0
# Episode 629 Total Rewards 188.0
# Episode 630 Total Rewards 266.0
# Episode 631 Total Rewards 251.0
# Episode 632 Total Rewards 224.0
# Episode 633 Total Rewards 500.0
# Episode 634 Total Rewards 406.0
# Episode 635 Total Rewards 241.0
# Episode 636 Total Rewards 241.0
# Episode 637 Total Rewards 233.0
# Episode 638 Total Rewards 265.0
# Episode 639 Total Rewards 370.0
# Episode 640 Total Rewards 277.0
# Episode 641 Total Rewards 500.0
# Episode 642 Total Rewards 422.0
# Episode 643 Total Rewards 311.0
# Episode 644 Total Rewards 309.0
# Episode 645 Total Rewards 213.0
# Episode 646 Total Rewards 387.0
# Episode 647 Total Rewards 193.0
# Episode 648 Total Rewards 234.0
# Episode 649 Total Rewards 395.0
# Episode 650 Total Rewards 381.0
# Episode 651 Total Rewards 332.0
# Episode 652 Total Rewards 232.0
# Episode 653 Total Rewards 455.0
# Episode 654 Total Rewards 402.0
# Episode 655 Total Rewards 250.0
# Episode 656 Total Rewards 394.0
# Episode 657 Total Rewards 500.0
# Episode 658 Total Rewards 500.0
# Episode 659 Total Rewards 250.0
# Episode 660 Total Rewards 463.0
# Episode 661 Total Rewards 389.0
# Episode 662 Total Rewards 416.0
# Episode 663 Total Rewards 462.0
# Episode 664 Total Rewards 500.0
# Episode 665 Total Rewards 246.0
# Episode 666 Total Rewards 500.0
# Episode 667 Total Rewards 459.0
# Episode 668 Total Rewards 351.0
# Episode 669 Total Rewards 408.0
# Episode 670 Total Rewards 337.0
# Episode 671 Total Rewards 105.0
# Episode 672 Total Rewards 224.0
# Episode 673 Total Rewards 285.0
# Episode 674 Total Rewards 286.0
# Episode 675 Total Rewards 500.0
# Episode 676 Total Rewards 239.0
# Episode 677 Total Rewards 467.0
# Episode 678 Total Rewards 316.0
# Episode 679 Total Rewards 500.0
# Episode 680 Total Rewards 500.0
# Episode 681 Total Rewards 295.0
# Episode 682 Total Rewards 215.0
# Episode 683 Total Rewards 109.0
# Episode 684 Total Rewards 250.0
# Episode 685 Total Rewards 251.0
# Episode 686 Total Rewards 463.0
# Episode 687 Total Rewards 365.0
# Episode 688 Total Rewards 259.0
# Episode 689 Total Rewards 421.0
# Episode 690 Total Rewards 500.0
# Episode 691 Total Rewards 391.0
# Episode 692 Total Rewards 357.0
# Episode 693 Total Rewards 500.0
# Episode 694 Total Rewards 399.0
# Episode 695 Total Rewards 254.0
# Episode 696 Total Rewards 454.0
# Episode 697 Total Rewards 319.0
# Episode 698 Total Rewards 382.0
# Episode 699 Total Rewards 400.0
# Episode 700 Total Rewards 500.0
# Episode 701 Total Rewards 500.0
# Episode 702 Total Rewards 311.0
# Episode 703 Total Rewards 405.0
# Episode 704 Total Rewards 68.0
# Episode 705 Total Rewards 263.0
# Episode 706 Total Rewards 308.0
# Episode 707 Total Rewards 383.0
# Episode 708 Total Rewards 396.0
# Episode 709 Total Rewards 500.0
# Episode 710 Total Rewards 402.0
# Episode 711 Total Rewards 277.0
# Episode 712 Total Rewards 500.0
# Episode 713 Total Rewards 500.0
# Episode 714 Total Rewards 500.0
# Episode 715 Total Rewards 251.0
# Episode 716 Total Rewards 500.0
# Episode 717 Total Rewards 434.0
# Episode 718 Total Rewards 392.0
# Episode 719 Total Rewards 226.0
# Episode 720 Total Rewards 157.0
# Episode 721 Total Rewards 500.0
# Episode 722 Total Rewards 446.0
# Episode 723 Total Rewards 500.0
# Episode 724 Total Rewards 398.0
# Episode 725 Total Rewards 261.0
# Episode 726 Total Rewards 375.0
# Episode 727 Total Rewards 235.0
# Episode 728 Total Rewards 500.0
# Episode 729 Total Rewards 434.0
# Episode 730 Total Rewards 343.0
# Episode 731 Total Rewards 232.0
# Episode 732 Total Rewards 434.0
# Episode 733 Total Rewards 250.0
# Episode 734 Total Rewards 199.0
# Episode 735 Total Rewards 206.0
# Episode 736 Total Rewards 278.0
# Episode 737 Total Rewards 373.0
# Episode 738 Total Rewards 500.0
# Episode 739 Total Rewards 500.0
# Episode 740 Total Rewards 357.0
# Episode 741 Total Rewards 500.0
# Episode 742 Total Rewards 407.0
# Episode 743 Total Rewards 428.0
# Episode 744 Total Rewards 500.0
# Episode 745 Total Rewards 500.0
# Episode 746 Total Rewards 407.0
# Episode 747 Total Rewards 500.0
# Episode 748 Total Rewards 283.0
# Episode 749 Total Rewards 500.0
# Episode 750 Total Rewards 437.0
# Episode 751 Total Rewards 309.0
# Episode 752 Total Rewards 298.0
# Episode 753 Total Rewards 271.0
# Episode 754 Total Rewards 357.0
# Episode 755 Total Rewards 414.0
# Episode 756 Total Rewards 500.0
# Episode 757 Total Rewards 500.0
# Episode 758 Total Rewards 500.0
# Episode 759 Total Rewards 500.0
# Episode 760 Total Rewards 213.0
# Episode 761 Total Rewards 500.0
# Episode 762 Total Rewards 350.0
# Episode 763 Total Rewards 500.0
# Episode 764 Total Rewards 500.0
# Episode 765 Total Rewards 427.0
# Episode 766 Total Rewards 316.0
# Episode 767 Total Rewards 500.0
# Episode 768 Total Rewards 430.0
# Episode 769 Total Rewards 200.0
# Episode 770 Total Rewards 500.0
# Episode 771 Total Rewards 184.0
# Episode 772 Total Rewards 363.0
# Episode 773 Total Rewards 500.0
# Episode 774 Total Rewards 429.0
# Episode 775 Total Rewards 205.0
# Episode 776 Total Rewards 384.0
# Episode 777 Total Rewards 414.0
# Episode 778 Total Rewards 315.0
# Episode 779 Total Rewards 500.0
# Episode 780 Total Rewards 357.0
# Episode 781 Total Rewards 228.0
# Episode 782 Total Rewards 500.0
# Episode 783 Total Rewards 317.0
# Episode 784 Total Rewards 272.0
# Episode 785 Total Rewards 500.0
# Episode 786 Total Rewards 346.0
# Episode 787 Total Rewards 500.0
# Episode 788 Total Rewards 389.0
# Episode 789 Total Rewards 500.0
# Episode 790 Total Rewards 151.0
# Episode 791 Total Rewards 234.0
# Episode 792 Total Rewards 500.0
# Episode 793 Total Rewards 500.0
# Episode 794 Total Rewards 108.0
# Episode 795 Total Rewards 326.0
# Episode 796 Total Rewards 500.0
# Episode 797 Total Rewards 229.0
# Episode 798 Total Rewards 500.0
# Episode 799 Total Rewards 444.0
# Episode 800 Total Rewards 500.0
# Episode 801 Total Rewards 500.0
# Episode 802 Total Rewards 500.0
# Episode 803 Total Rewards 500.0
# Episode 804 Total Rewards 500.0
# Episode 805 Total Rewards 170.0
# Episode 806 Total Rewards 500.0
# Episode 807 Total Rewards 275.0
# Episode 808 Total Rewards 500.0
# Episode 809 Total Rewards 500.0
# Episode 810 Total Rewards 464.0
# Episode 811 Total Rewards 326.0
# Episode 812 Total Rewards 281.0
# Episode 813 Total Rewards 500.0
# Episode 814 Total Rewards 201.0
# Episode 815 Total Rewards 216.0
# Episode 816 Total Rewards 382.0
# Episode 817 Total Rewards 227.0
# Episode 818 Total Rewards 372.0
# Episode 819 Total Rewards 291.0
# Episode 820 Total Rewards 463.0
# Episode 821 Total Rewards 294.0
# Episode 822 Total Rewards 500.0
# Episode 823 Total Rewards 219.0
# Episode 824 Total Rewards 304.0
# Episode 825 Total Rewards 210.0
# Episode 826 Total Rewards 380.0
# Episode 827 Total Rewards 295.0
# Episode 828 Total Rewards 500.0
# Episode 829 Total Rewards 247.0
# Episode 830 Total Rewards 287.0
# Episode 831 Total Rewards 500.0
# Episode 832 Total Rewards 308.0
# Episode 833 Total Rewards 500.0
# Episode 834 Total Rewards 158.0
# Episode 835 Total Rewards 401.0
# Episode 836 Total Rewards 500.0
# Episode 837 Total Rewards 370.0
# Episode 838 Total Rewards 257.0
# Episode 839 Total Rewards 280.0
# Episode 840 Total Rewards 500.0
# Episode 841 Total Rewards 335.0
# Episode 842 Total Rewards 185.0
# Episode 843 Total Rewards 252.0
# Episode 844 Total Rewards 158.0
# Episode 845 Total Rewards 205.0
# Episode 846 Total Rewards 349.0
# Episode 847 Total Rewards 500.0
# Episode 848 Total Rewards 500.0
# Episode 849 Total Rewards 260.0
# Episode 850 Total Rewards 347.0
# Episode 851 Total Rewards 362.0
# Episode 852 Total Rewards 389.0
# Episode 853 Total Rewards 367.0
# Episode 854 Total Rewards 204.0
# Episode 855 Total Rewards 500.0
# Episode 856 Total Rewards 397.0
# Episode 857 Total Rewards 299.0
# Episode 858 Total Rewards 340.0
# Episode 859 Total Rewards 206.0
# Episode 860 Total Rewards 349.0
# Episode 861 Total Rewards 273.0
# Episode 862 Total Rewards 337.0
# Episode 863 Total Rewards 220.0
# Episode 864 Total Rewards 241.0
# Episode 865 Total Rewards 477.0
# Episode 866 Total Rewards 380.0
# Episode 867 Total Rewards 500.0
# Episode 868 Total Rewards 324.0
# Episode 869 Total Rewards 478.0
# Episode 870 Total Rewards 294.0
# Episode 871 Total Rewards 500.0
# Episode 872 Total Rewards 228.0
# Episode 873 Total Rewards 268.0
# Episode 874 Total Rewards 393.0
# Episode 875 Total Rewards 270.0
# Episode 876 Total Rewards 402.0
# Episode 877 Total Rewards 304.0
# Episode 878 Total Rewards 228.0
# Episode 879 Total Rewards 500.0
# Episode 880 Total Rewards 414.0
# Episode 881 Total Rewards 500.0
# Episode 882 Total Rewards 406.0
# Episode 883 Total Rewards 500.0
# Episode 884 Total Rewards 259.0
# Episode 885 Total Rewards 310.0
# Episode 886 Total Rewards 500.0
# Episode 887 Total Rewards 500.0
# Episode 888 Total Rewards 320.0
# Episode 889 Total Rewards 367.0
# Episode 890 Total Rewards 500.0
# Episode 891 Total Rewards 472.0
# Episode 892 Total Rewards 500.0
# Episode 893 Total Rewards 500.0
# Episode 894 Total Rewards 220.0
# Episode 895 Total Rewards 500.0
# Episode 896 Total Rewards 394.0
# Episode 897 Total Rewards 500.0
# Episode 898 Total Rewards 250.0
# Episode 899 Total Rewards 500.0
# Episode 900 Total Rewards 500.0
# Episode 901 Total Rewards 464.0
# Episode 902 Total Rewards 500.0
# Episode 903 Total Rewards 238.0
# Episode 904 Total Rewards 500.0
# Episode 905 Total Rewards 409.0
# Episode 906 Total Rewards 325.0
# Episode 907 Total Rewards 290.0
# Episode 908 Total Rewards 500.0
# Episode 909 Total Rewards 390.0
# Episode 910 Total Rewards 499.0
# Episode 911 Total Rewards 325.0
# Episode 912 Total Rewards 500.0
# Episode 913 Total Rewards 500.0
# Episode 914 Total Rewards 379.0
# Episode 915 Total Rewards 344.0
# Episode 916 Total Rewards 500.0
# Episode 917 Total Rewards 500.0
# Episode 918 Total Rewards 500.0
# Episode 919 Total Rewards 129.0
# Episode 920 Total Rewards 434.0
# Episode 921 Total Rewards 500.0
# Episode 922 Total Rewards 500.0
# Episode 923 Total Rewards 500.0
# Episode 924 Total Rewards 446.0
# Episode 925 Total Rewards 500.0
# Episode 926 Total Rewards 500.0
# Episode 927 Total Rewards 420.0
# Episode 928 Total Rewards 495.0
# Episode 929 Total Rewards 340.0
# Episode 930 Total Rewards 500.0
# Episode 931 Total Rewards 310.0
# Episode 932 Total Rewards 500.0
# Episode 933 Total Rewards 500.0
# Episode 934 Total Rewards 500.0
# Episode 935 Total Rewards 343.0
# Episode 936 Total Rewards 180.0
# Episode 937 Total Rewards 493.0
# Episode 938 Total Rewards 500.0
# Episode 939 Total Rewards 500.0
# Episode 940 Total Rewards 239.0
# Episode 941 Total Rewards 500.0
# Episode 942 Total Rewards 500.0
# Episode 943 Total Rewards 500.0
# Episode 944 Total Rewards 288.0
# Episode 945 Total Rewards 423.0
# Episode 946 Total Rewards 500.0
# Episode 947 Total Rewards 317.0
# Episode 948 Total Rewards 500.0
# Episode 949 Total Rewards 341.0
# Episode 950 Total Rewards 252.0
# Episode 951 Total Rewards 500.0
# Episode 952 Total Rewards 355.0
# Episode 953 Total Rewards 500.0
# Episode 954 Total Rewards 233.0
# Episode 955 Total Rewards 500.0
# Episode 956 Total Rewards 500.0
# Episode 957 Total Rewards 500.0
# Episode 958 Total Rewards 469.0
# Episode 959 Total Rewards 426.0
# Episode 960 Total Rewards 299.0
# Episode 961 Total Rewards 242.0
# Episode 962 Total Rewards 500.0
# Episode 963 Total Rewards 383.0
# Episode 964 Total Rewards 382.0
# Episode 965 Total Rewards 500.0
# Episode 966 Total Rewards 500.0
# Episode 967 Total Rewards 272.0
# Episode 968 Total Rewards 500.0
# Episode 969 Total Rewards 305.0
# Episode 970 Total Rewards 257.0
# Episode 971 Total Rewards 499.0
# Episode 972 Total Rewards 173.0
# Episode 973 Total Rewards 221.0
# Episode 974 Total Rewards 500.0
# Episode 975 Total Rewards 455.0
# Episode 976 Total Rewards 201.0
# Episode 977 Total Rewards 286.0
# Episode 978 Total Rewards 186.0
# Episode 979 Total Rewards 352.0
# Episode 980 Total Rewards 303.0
# Episode 981 Total Rewards 500.0
# Episode 982 Total Rewards 500.0
# Episode 983 Total Rewards 223.0
# Episode 984 Total Rewards 500.0
# Episode 985 Total Rewards 500.0
# Episode 986 Total Rewards 433.0
# Episode 987 Total Rewards 500.0
# Episode 988 Total Rewards 500.0
# Episode 989 Total Rewards 456.0
# Episode 990 Total Rewards 122.0
# Episode 991 Total Rewards 359.0
# Episode 992 Total Rewards 210.0
# Episode 993 Total Rewards 500.0
# Episode 994 Total Rewards 500.0
# Episode 995 Total Rewards 255.0
# Episode 996 Total Rewards 296.0
# Episode 997 Total Rewards 500.0
# Episode 998 Total Rewards 500.0
# Episode 999 Total Rewards 500.0
